# %%
import random
import os

import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.neuron as tfn
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import roc_auc_score
# Out:
# 2024-03-18 08:40:26.549851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-18 08:40:26.661484: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/lib
# 2024-03-18 08:40:26.661509: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-03-18 08:40:26.688308: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-18 08:40:27.223626: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/lib
# 2024-03-18 08:40:27.223692: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/lib
# 2024-03-18 08:40:27.223699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-03-18 08:40:27.728168: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/lib
# 2024-03-18 08:40:27.728191: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-03-18 08:40:27.728206: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-21-241): /proc/driver/nvidia/version does not exist

# %%
from mmoe import MMoE

SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

# %%
# Simple callback to print out ROC-AUC
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return


def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        'data/census-income.data.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        'data/census-income.test.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info

# %%
# Load the data
train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
num_features = train_data.shape[1]

print('Training data shape = {}'.format(train_data.shape))
print('Validation data shape = {}'.format(validation_data.shape))
print('Test data shape = {}'.format(test_data.shape))

# Set up the input layer
input_layer = Input(shape=(num_features,))

# Set up MMoE layer
mmoe_layers = MMoE(
    units=4,
    num_experts=8,
    num_tasks=2
)(input_layer)

output_layers = []

# Build tower layer from MMoE layer
for index, task_layer in enumerate(mmoe_layers):
    tower_layer = Dense(
        units=8,
        activation='relu',
        kernel_initializer=VarianceScaling())(task_layer)
    output_layer = Dense(
        units=output_info[index][0],
        name=output_info[index][1],
        activation='softmax',
        kernel_initializer=VarianceScaling())(tower_layer)
    output_layers.append(output_layer)

# Compile model
model = Model(inputs=[input_layer], outputs=output_layers)
adam_optimizer = Adam()
model.compile(
    loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
    optimizer=adam_optimizer,
    metrics=['accuracy']
)
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)
# 2024-03-18 08:40:31.372846: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ubuntu/aws_neuron_venv_tensorflow_inf1/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer VarianceScaling is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
train_data = train_data.astype(float)
validation_data = validation_data.astype(float)
test_data = test_data.astype(float)

# %%
model.fit(
        x=train_data,
        y=train_label,
        epochs=1
    )
# Out:
# 6236/6236 [==============================] - 9s 1ms/step - loss: 0.6877 - income_loss: 0.3235 - marital_loss: 0.3642 - income_accuracy: 0.9369 - marital_accuracy: 0.8312

# %%
model_dir = './model/mmoe'   
model.save(model_dir)
# Out:
# INFO:tensorflow:Assets written to: ./model/mmoe/assets

# %%
loaded_model = tf.keras.models.load_model(model_dir)
example_inputs = tf.random.uniform([0, 499])
tfn.analyze_model(loaded_model, example_inputs)
# Out:
# The following operations are currently supported in tensorflow-neuron for this model:
# Softmax
# Relu
# MatMul
# BiasAdd
# The following operations are currently not supported in tensorflow-neuron for this model:
# StatefulPartitionedCall
# 92.31% of all operations (12 of 13) are supported
# {'percent_supported': 92.3076923076923,
#  'supported_count': 12,
#  'total_count': 13,
#  'supported_operators': {'BiasAdd', 'MatMul', 'Relu', 'Softmax'},
#  'unsupported_operators': ['StatefulPartitionedCall'],
#  'operators': ['BiasAdd',
#   'MatMul',
#   'Relu',
#   'Softmax',
#   'StatefulPartitionedCall'],
#  'operator_count': {'StatefulPartitionedCall': 1,
#   'MatMul': 4,
#   'BiasAdd': 4,
#   'Relu': 2,
#   'Softmax': 2}}

# %%
output = loaded_model.predict(test_data)
output
# Out:
# 1559/1559 [==============================] - 1s 807us/step
# [array([[0.9956274 , 0.00437255],
#         [0.9956274 , 0.00437255],
#         [0.9956274 , 0.00437255],
#         ...,
#         [0.9956274 , 0.00437255],
#         [0.9956274 , 0.00437255],
#         [0.9956274 , 0.00437255]], dtype=float32),
#  array([[9.9177831e-01, 8.2216049e-03],
#         [5.1579947e-05, 9.9994832e-01],
#         [1.2167198e-04, 9.9987823e-01],
#         ...,
#         [9.9181008e-01, 8.1898617e-03],
#         [9.4658452e-01, 5.3415503e-02],
#         [9.9388486e-01, 6.1151166e-03]], dtype=float32)]

# %%
neuron_model = tfn.trace(loaded_model, test_data)  # trace
# Out:
# 2024-03-18 08:40:47.145479: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-03-18 08:40:47.145635: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-03-18 08:40:47.344537: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-03-18 08:40:47.344630: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-03-18 08:40:47.571062: I tensorflow/neuron/grappler/convert/segment.cc:456] There are 5 ops of 2 different types in the graph that are not compiled by neuron-cc: Placeholder, NoOp, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/neuron-cc-ops/neuron-cc-ops-tensorflow.html).
# 2024-03-18 08:40:47.586813: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-03-18 08:40:47.586919: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-03-18 08:40:47.734335: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-18 08:40:47.737657: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# .complexity:  884
#
# TensorContractLayout 0 block=j_0=[0:4:1] load_par=k=[0:499:1] store_par=j_1=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=784, parallel_axes_tripcount=1024)
# 	l 91 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 89 input4   [499, 4, 8] [P,B,F] ['k', 'j_0', 'j_1']
# 	r           float32 $309[i,j_0,j_1] = tensor_contract_multiply_add(float32 $91[i,j_0,j_1,k], float32 $89[i,j_0,j_1,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j_0=[0:4:1],j_1=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Tensordot/MatMul_dot.81
# 	l 100 input3   [4, 8] [B,P] ['j_0', 'j_1']
# 	s 109 mhlo_maximum_5   [49881, 4, 8] [F,B,P] ['i', 'j_0', 'j_1']
#
#
#
# TensorContractLayout 1 block= load_par=k=[0:499:1] store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=1024)
# 	l 115 input5   [8] [P] ['j']
# 	l 110 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 111 input1   [499, 8] [P,F] ['k', 'j']
# 	r         float32 $310[i,j] = tensor_contract_multiply_add(float32 $110[i,j,k], float32 $111[i,j,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/MatMul_dot.15
# 	s 120 mhlo_add_8   [49881, 8] [F,P] ['i', 'j']
#
#
#
# DFNLayout 2 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 121 mhlo_add_8   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $122[i] = reduce_maximum(float32 $121[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_reduce.27
# 	s 125 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9   [49881] [P] ['i']
#
#
#
# DFNLayout 3 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 126 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9   [49881] [P] ['i']
# 	l 128 mhlo_add_8   [49881, 8] [P,F] ['i', 'j']
# 	s 134 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
#
#
#
# DFNLayout 4 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 135 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $136[i] = reduce_add(float32 $135[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_reduce.38
# 	s 139 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13   [49881] [P] ['i']
#
#
#
# DFNLayout 5 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 140 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13   [49881] [P] ['i']
# 	l 142 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
# 	s 145 mhlo_divide_15   [49881, 8] [P,F] ['i', 'j']
#
#
#
# TensorContractLayout 6 block=i=[0:49881:1] j=[0:4:1] load_par=k=[0:8:1] store_par= free=
# layout_profile(block_axes_tripcount=199524, parallel_axes_tripcount=8)
# 	l 146 mhlo_divide_15   [49881, 8] [B,P] ['i', 'k']
# 	l 148 mhlo_maximum_5   [49881, 4, 8] [B,B,P] ['i', 'j', 'k']
# 	r         float32 $317[i,j] = tensor_contract_multiply_add(float32 $148[i,j,k], float32 $146[i,j,k], contract={k=[0:8:1]}, lhs_free={j=[0:4:1]}, rhs_free={}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Sum_reduce.99
# 	s 156 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18   [49881, 4] [B,B] ['i', 'j']
#
#
#
# TensorContractLayout 7 block=k=[0:4:1] load_par= store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=8)
# 	l 162 model_dense_BiasAdd_constant_104_hlo_id_104__mhlo.constant_8  const [8] [P] ['j']
# 	l 157 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18   [49881, 4] [F,B] ['i', 'k']
# 	l 158 model_dense_MatMul_constant_101_hlo_id_101__mhlo.constant_7  const [4, 8] [B,F] ['k', 'j']
# 	r         float32 $311[i,j] = tensor_contract_multiply_add(float32 $157[i,j,k], float32 $158[i,j,k], contract={k=[0:4:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/dense/MatMul_dot.102
# 	s 173 mhlo_maximum_22   [49881, 8] [F,P] ['i', 'j']
#
#
#
# TensorContractLayout 8 block=j=[0:2:1] load_par=k=[0:8:1] store_par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=8)
# 	l 179 model_income_BiasAdd_constant_113_hlo_id_113__mhlo.constant_12  const [2] [B] ['j']
# 	l 174 mhlo_maximum_22   [49881, 8] [F,P] ['i', 'k']
# 	l 175 model_income_MatMul_constant_110_hlo_id_110__mhlo.constant_11  const [8, 2] [P,B] ['k', 'j']
# 	r         float32 $312[i,j] = tensor_contract_multiply_add(float32 $174[i,j,k], float32 $175[i,j,k], contract={k=[0:8:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:2:1]}) # dl = model/income/MatMul_dot.111
# 	s 184 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 9 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 185 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $186[i] = reduce_maximum(float32 $185[i,j], {j=[0:2:1]}) # dl = model/income/Softmax_reduce.122
# 	s 189 model_income_Softmax_reduce_122_hlo_id_122__26   [49881] [F] ['i']
#
#
#
# DFNLayout 10 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 190 model_income_Softmax_reduce_122_hlo_id_122__26   [49881] [F] ['i']
# 	l 192 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
# 	s 198 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 11 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 199 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $200[i] = reduce_add(float32 $199[i,j], {j=[0:2:1]}) # dl = model/income/Softmax_reduce.133
# 	s 203 model_income_Softmax_reduce_133_hlo_id_133__30   [49881] [F] ['i']
#
#
#
# DFNLayout 12 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 204 model_income_Softmax_reduce_133_hlo_id_133__30   [49881] [F] ['i']
# 	l 206 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
# 	s 209 output0   [49881, 2] [F,B] ['i', 'j']
#
#
#
# TensorContractLayout 13 block= load_par=k=[0:499:1] store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=1024)
# 	l 215 input6   [8] [P] ['j']
# 	l 210 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 211 input2   [499, 8] [P,F] ['k', 'j']
# 	r         float32 $313[i,j] = tensor_contract_multiply_add(float32 $210[i,j,k], float32 $211[i,j,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/MatMul_1_dot.17
# 	s 220 mhlo_add_35   [49881, 8] [F,P] ['i', 'j']
#
#
#
# DFNLayout 14 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 221 mhlo_add_35   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $222[i] = reduce_maximum(float32 $221[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_1_reduce.52
# 	s 225 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36   [49881] [P] ['i']
#
#
#
# DFNLayout 15 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 226 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36   [49881] [P] ['i']
# 	l 228 mhlo_add_35   [49881, 8] [P,F] ['i', 'j']
# 	s 234 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
#
#
#
# DFNLayout 16 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 235 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $236[i] = reduce_add(float32 $235[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_1_reduce.63
# 	s 239 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40   [49881] [P] ['i']
#
#
#
# DFNLayout 17 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 240 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40   [49881] [P] ['i']
# 	l 242 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
# 	s 245 mhlo_divide_42   [49881, 8] [P,F] ['i', 'j']
#
#
#
# TensorContractLayout 18 block=i=[0:49881:1] j=[0:4:1] load_par=k=[0:8:1] store_par= free=
# layout_profile(block_axes_tripcount=199524, parallel_axes_tripcount=8)
# 	l 246 mhlo_divide_42   [49881, 8] [B,P] ['i', 'k']
# 	l 248 mhlo_maximum_5   [49881, 4, 8] [B,B,P] ['i', 'j', 'k']
# 	r         float32 $318[i,j] = tensor_contract_multiply_add(float32 $248[i,j,k], float32 $246[i,j,k], contract={k=[0:8:1]}, lhs_free={j=[0:4:1]}, rhs_free={}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Sum_1_reduce.147
# 	s 256 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45   [49881, 4] [B,B] ['i', 'j']
#
#
#
# TensorContractLayout 19 block=k=[0:4:1] load_par= store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=8)
# 	l 262 model_dense_1_BiasAdd_constant_152_hlo_id_152__mhlo.constant_14  const [8] [P] ['j']
# 	l 257 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45   [49881, 4] [F,B] ['i', 'k']
# 	l 258 model_dense_1_MatMul_constant_149_hlo_id_149__mhlo.constant_13  const [4, 8] [B,F] ['k', 'j']
# 	r         float32 $314[i,j] = tensor_contract_multiply_add(float32 $257[i,j,k], float32 $258[i,j,k], contract={k=[0:4:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/dense_1/MatMul_dot.150
# 	s 271 mhlo_maximum_49   [49881, 8] [F,P] ['i', 'j']
#
#
#
# TensorContractLayout 20 block=j=[0:2:1] load_par=k=[0:8:1] store_par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=8)
# 	l 277 model_marital_BiasAdd_constant_161_hlo_id_161__mhlo.constant_16  const [2] [B] ['j']
# 	l 272 mhlo_maximum_49   [49881, 8] [F,P] ['i', 'k']
# 	l 273 model_marital_MatMul_constant_158_hlo_id_158__mhlo.constant_15  const [8, 2] [P,B] ['k', 'j']
# 	r         float32 $315[i,j] = tensor_contract_multiply_add(float32 $272[i,j,k], float32 $273[i,j,k], contract={k=[0:8:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:2:1]}) # dl = model/marital/MatMul_dot.159
# 	s 282 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 21 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 283 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $284[i] = reduce_maximum(float32 $283[i,j], {j=[0:2:1]}) # dl = model/marital/Softmax_reduce.170
# 	s 287 model_marital_Softmax_reduce_170_hlo_id_170__53   [49881] [F] ['i']
#
#
#
# DFNLayout 22 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 288 model_marital_Softmax_reduce_170_hlo_id_170__53   [49881] [F] ['i']
# 	l 290 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
# 	s 296 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 23 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 297 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $298[i] = reduce_add(float32 $297[i,j], {j=[0:2:1]}) # dl = model/marital/Softmax_reduce.181
# 	s 301 model_marital_Softmax_reduce_181_hlo_id_181__57   [49881] [F] ['i']
#
#
#
# DFNLayout 24 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 302 model_marital_Softmax_reduce_181_hlo_id_181__57   [49881] [F] ['i']
# 	l 304 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
# 	s 307 output1   [49881, 2] [F,B] ['i', 'j']
#
#
#
# mhlo_divide_42 - [49881, 8], tensor_layout: [P,F]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=391, num_pf_transposes=1, num_bf_transposes=1)
#  access_layout [B,P], accesses: ['246 L'], path: [[_pf_transpose,_pf_transpose], [_bf_transpose,_identity]]
#  access_layout [P,F], accesses: ['245 S'], path: [[_identity,_identity]]
# mhlo_divide_15 - [49881, 8], tensor_layout: [P,F]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=391, num_pf_transposes=1, num_bf_transposes=1)
#  access_layout [B,P], accesses: ['146 L'], path: [[_pf_transpose,_pf_transpose], [_bf_transpose,_identity]]
#  access_layout [P,F], accesses: ['145 S'], path: [[_identity,_identity]]
# mhlo_add_35 - [49881, 8], tensor_layout: [F,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=390, num_pf_transposes=1, num_bf_transposes=0)
#  access_layout [F,P], accesses: ['220 S'], path: [[_identity,_identity]]
#  access_layout [P,F], accesses: ['221 L', '228 L'], path: [[_pf_transpose,_pf_transpose]]
# mhlo_add_8 - [49881, 8], tensor_layout: [F,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=390, num_pf_transposes=1, num_bf_transposes=0)
#  access_layout [F,P], accesses: ['120 S'], path: [[_identity,_identity]]
#  access_layout [P,F], accesses: ['121 L', '128 L'], path: [[_pf_transpose,_pf_transpose]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45 - [49881, 4], tensor_layout: [F,B]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [B,B], accesses: ['256 S'], path: [[_bf_transpose,_identity]]
#  access_layout [F,B], accesses: ['257 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18 - [49881, 4], tensor_layout: [F,B]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [B,B], accesses: ['156 S'], path: [[_bf_transpose,_identity]]
#  access_layout [F,B], accesses: ['157 L'], path: [[_identity,_identity]]
# mhlo_maximum_5 - [49881, 4, 8], tensor_layout: [F,B,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [F,B,P], accesses: ['109 S'], path: [[_identity,_identity,_identity]]
#  access_layout [B,B,P], accesses: ['148 L', '248 L'], path: [[_bf_transpose,_identity,_identity]]
# model_marital_Softmax_reduce_181_hlo_id_181__57 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['301 S', '302 L'], path: [[_identity]]
# mhlo_exponential_56 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['296 S', '297 L', '304 L'], path: [[_identity,_identity]]
# model_marital_Softmax_reduce_170_hlo_id_170__53 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['287 S', '288 L'], path: [[_identity]]
# mhlo_add_52 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['282 S', '283 L', '290 L'], path: [[_identity,_identity]]
# mhlo_maximum_49 - [49881, 8], tensor_layout: [F,P]
#  access_layout [F,P], accesses: ['271 S', '272 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['239 S', '240 L'], path: [[_identity]]
# mhlo_exponential_39 - [49881, 8], tensor_layout: [P,F]
#  access_layout [P,F], accesses: ['234 S', '235 L', '242 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['225 S', '226 L'], path: [[_identity]]
# model_income_Softmax_reduce_133_hlo_id_133__30 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['203 S', '204 L'], path: [[_identity]]
# mhlo_exponential_29 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['198 S', '199 L', '206 L'], path: [[_identity,_identity]]
# model_income_Softmax_reduce_122_hlo_id_122__26 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['189 S', '190 L'], path: [[_identity]]
# mhlo_add_25 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['184 S', '185 L', '192 L'], path: [[_identity,_identity]]
# mhlo_maximum_22 - [49881, 8], tensor_layout: [F,P]
#  access_layout [F,P], accesses: ['173 S', '174 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['139 S', '140 L'], path: [[_identity]]
# mhlo_exponential_12 - [49881, 8], tensor_layout: [P,F]
#  access_layout [P,F], accesses: ['134 S', '135 L', '142 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['125 S', '126 L'], path: [[_identity]]
# layoutgroup_profile(total_dmas=0, total_tripcount=406290, total_transpose_tripcount=1574, total_pf_transposes=4, total_bf_transposes=5, block_axes_tripcount=404716, parallel_axes_tripcount=4152, dags_no_parallelism=8)
# complexity:  884
#
# TensorContractLayout 0 block=j_0=[0:4:1] load_par=k=[0:499:1] store_par=j_1=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=784, parallel_axes_tripcount=1024)
# 	l 91 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 89 input4   [499, 4, 8] [P,B,F] ['k', 'j_0', 'j_1']
# 	r           float32 $309[i,j_0,j_1] = tensor_contract_multiply_add(float32 $91[i,j_0,j_1,k], float32 $89[i,j_0,j_1,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j_0=[0:4:1],j_1=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Tensordot/MatMul_dot.81
# 	l 100 input3   [4, 8] [B,P] ['j_0', 'j_1']
# 	s 109 mhlo_maximum_5   [49881, 4, 8] [F,B,P] ['i', 'j_0', 'j_1']
#
#
#
# TensorContractLayout 1 block= load_par=k=[0:499:1] store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=1024)
# 	l 115 input5   [8] [P] ['j']
# 	l 110 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 111 input1   [499, 8] [P,F] ['k', 'j']
# 	r         float32 $310[i,j] = tensor_contract_multiply_add(float32 $110[i,j,k], float32 $111[i,j,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/MatMul_dot.15
# 	s 120 mhlo_add_8   [49881, 8] [F,P] ['i', 'j']
#
#
#
# DFNLayout 2 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 121 mhlo_add_8   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $122[i] = reduce_maximum(float32 $121[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_reduce.27
# 	s 125 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9   [49881] [P] ['i']
#
#
#
# DFNLayout 3 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 126 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9   [49881] [P] ['i']
# 	l 128 mhlo_add_8   [49881, 8] [P,F] ['i', 'j']
# 	s 134 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
#
#
#
# DFNLayout 4 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 135 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $136[i] = reduce_add(float32 $135[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_reduce.38
# 	s 139 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13   [49881] [P] ['i']
#
#
#
# DFNLayout 5 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 140 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13   [49881] [P] ['i']
# 	l 142 mhlo_exponential_12   [49881, 8] [P,F] ['i', 'j']
# 	s 145 mhlo_divide_15   [49881, 8] [P,F] ['i', 'j']
#
#
#
# TensorContractLayout 6 block=i=[0:49881:1] j=[0:4:1] load_par=k=[0:8:1] store_par= free=
# layout_profile(block_axes_tripcount=199524, parallel_axes_tripcount=8)
# 	l 146 mhlo_divide_15   [49881, 8] [B,P] ['i', 'k']
# 	l 148 mhlo_maximum_5   [49881, 4, 8] [B,B,P] ['i', 'j', 'k']
# 	r         float32 $317[i,j] = tensor_contract_multiply_add(float32 $148[i,j,k], float32 $146[i,j,k], contract={k=[0:8:1]}, lhs_free={j=[0:4:1]}, rhs_free={}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Sum_reduce.99
# 	s 156 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18   [49881, 4] [B,B] ['i', 'j']
#
#
#
# TensorContractLayout 7 block=k=[0:4:1] load_par= store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=8)
# 	l 162 model_dense_BiasAdd_constant_104_hlo_id_104__mhlo.constant_8  const [8] [P] ['j']
# 	l 157 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18   [49881, 4] [F,B] ['i', 'k']
# 	l 158 model_dense_MatMul_constant_101_hlo_id_101__mhlo.constant_7  const [4, 8] [B,F] ['k', 'j']
# 	r         float32 $311[i,j] = tensor_contract_multiply_add(float32 $157[i,j,k], float32 $158[i,j,k], contract={k=[0:4:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/dense/MatMul_dot.102
# 	s 173 mhlo_maximum_22   [49881, 8] [F,P] ['i', 'j']
#
#
#
# TensorContractLayout 8 block=j=[0:2:1] load_par=k=[0:8:1] store_par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=8)
# 	l 179 model_income_BiasAdd_constant_113_hlo_id_113__mhlo.constant_12  const [2] [B] ['j']
# 	l 174 mhlo_maximum_22   [49881, 8] [F,P] ['i', 'k']
# 	l 175 model_income_MatMul_constant_110_hlo_id_110__mhlo.constant_11  const [8, 2] [P,B] ['k', 'j']
# 	r         float32 $312[i,j] = tensor_contract_multiply_add(float32 $174[i,j,k], float32 $175[i,j,k], contract={k=[0:8:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:2:1]}) # dl = model/income/MatMul_dot.111
# 	s 184 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 9 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 185 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $186[i] = reduce_maximum(float32 $185[i,j], {j=[0:2:1]}) # dl = model/income/Softmax_reduce.122
# 	s 189 model_income_Softmax_reduce_122_hlo_id_122__26   [49881] [F] ['i']
#
#
#
# DFNLayout 10 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 190 model_income_Softmax_reduce_122_hlo_id_122__26   [49881] [F] ['i']
# 	l 192 mhlo_add_25   [49881, 2] [F,B] ['i', 'j']
# 	s 198 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 11 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 199 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $200[i] = reduce_add(float32 $199[i,j], {j=[0:2:1]}) # dl = model/income/Softmax_reduce.133
# 	s 203 model_income_Softmax_reduce_133_hlo_id_133__30   [49881] [F] ['i']
#
#
#
# DFNLayout 12 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 204 model_income_Softmax_reduce_133_hlo_id_133__30   [49881] [F] ['i']
# 	l 206 mhlo_exponential_29   [49881, 2] [F,B] ['i', 'j']
# 	s 209 output0   [49881, 2] [F,B] ['i', 'j']
#
#
#
# TensorContractLayout 13 block= load_par=k=[0:499:1] store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=1024)
# 	l 215 input6   [8] [P] ['j']
# 	l 210 input0   [49881, 499] [F,P] ['i', 'k']
# 	l 211 input2   [499, 8] [P,F] ['k', 'j']
# 	r         float32 $313[i,j] = tensor_contract_multiply_add(float32 $210[i,j,k], float32 $211[i,j,k], contract={k=[0:499:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/MatMul_1_dot.17
# 	s 220 mhlo_add_35   [49881, 8] [F,P] ['i', 'j']
#
#
#
# DFNLayout 14 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 221 mhlo_add_35   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $222[i] = reduce_maximum(float32 $221[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_1_reduce.52
# 	s 225 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36   [49881] [P] ['i']
#
#
#
# DFNLayout 15 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 226 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36   [49881] [P] ['i']
# 	l 228 mhlo_add_35   [49881, 8] [P,F] ['i', 'j']
# 	s 234 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
#
#
#
# DFNLayout 16 broadcast= block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 235 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
# 	r       float32 $236[i] = reduce_add(float32 $235[i,j], {j=[0:8:1]}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Softmax_1_reduce.63
# 	s 239 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40   [49881] [P] ['i']
#
#
#
# DFNLayout 17 broadcast=j=[0:8:1] block= par=i=[0:49881:1] free=j=[0:8:1]
# layout_profile(block_axes_tripcount=390, parallel_axes_tripcount=128)
# 	l 240 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40   [49881] [P] ['i']
# 	l 242 mhlo_exponential_39   [49881, 8] [P,F] ['i', 'j']
# 	s 245 mhlo_divide_42   [49881, 8] [P,F] ['i', 'j']
#
#
#
# TensorContractLayout 18 block=i=[0:49881:1] j=[0:4:1] load_par=k=[0:8:1] store_par= free=
# layout_profile(block_axes_tripcount=199524, parallel_axes_tripcount=8)
# 	l 246 mhlo_divide_42   [49881, 8] [B,P] ['i', 'k']
# 	l 248 mhlo_maximum_5   [49881, 4, 8] [B,B,P] ['i', 'j', 'k']
# 	r         float32 $318[i,j] = tensor_contract_multiply_add(float32 $248[i,j,k], float32 $246[i,j,k], contract={k=[0:8:1]}, lhs_free={j=[0:4:1]}, rhs_free={}) # dl = model/m_mo_e/StatefulPartitionedCall/StatefulPartitionedCall/Sum_1_reduce.147
# 	s 256 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45   [49881, 4] [B,B] ['i', 'j']
#
#
#
# TensorContractLayout 19 block=k=[0:4:1] load_par= store_par=j=[0:8:1] free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=196, parallel_axes_tripcount=8)
# 	l 262 model_dense_1_BiasAdd_constant_152_hlo_id_152__mhlo.constant_14  const [8] [P] ['j']
# 	l 257 model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45   [49881, 4] [F,B] ['i', 'k']
# 	l 258 model_dense_1_MatMul_constant_149_hlo_id_149__mhlo.constant_13  const [4, 8] [B,F] ['k', 'j']
# 	r         float32 $314[i,j] = tensor_contract_multiply_add(float32 $257[i,j,k], float32 $258[i,j,k], contract={k=[0:4:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:8:1]}) # dl = model/dense_1/MatMul_dot.150
# 	s 271 mhlo_maximum_49   [49881, 8] [F,P] ['i', 'j']
#
#
#
# TensorContractLayout 20 block=j=[0:2:1] load_par=k=[0:8:1] store_par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=8)
# 	l 277 model_marital_BiasAdd_constant_161_hlo_id_161__mhlo.constant_16  const [2] [B] ['j']
# 	l 272 mhlo_maximum_49   [49881, 8] [F,P] ['i', 'k']
# 	l 273 model_marital_MatMul_constant_158_hlo_id_158__mhlo.constant_15  const [8, 2] [P,B] ['k', 'j']
# 	r         float32 $315[i,j] = tensor_contract_multiply_add(float32 $272[i,j,k], float32 $273[i,j,k], contract={k=[0:8:1]}, lhs_free={i=[0:49881:1]}, rhs_free={j=[0:2:1]}) # dl = model/marital/MatMul_dot.159
# 	s 282 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 21 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 283 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $284[i] = reduce_maximum(float32 $283[i,j], {j=[0:2:1]}) # dl = model/marital/Softmax_reduce.170
# 	s 287 model_marital_Softmax_reduce_170_hlo_id_170__53   [49881] [F] ['i']
#
#
#
# DFNLayout 22 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 288 model_marital_Softmax_reduce_170_hlo_id_170__53   [49881] [F] ['i']
# 	l 290 mhlo_add_52   [49881, 2] [F,B] ['i', 'j']
# 	s 296 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
#
#
#
# DFNLayout 23 broadcast= block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 297 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
# 	r       float32 $298[i] = reduce_add(float32 $297[i,j], {j=[0:2:1]}) # dl = model/marital/Softmax_reduce.181
# 	s 301 model_marital_Softmax_reduce_181_hlo_id_181__57   [49881] [F] ['i']
#
#
#
# DFNLayout 24 broadcast=j=[0:2:1] block=j=[0:2:1] par= free=i=[0:49881:1]
# layout_profile(block_axes_tripcount=98, parallel_axes_tripcount=1)
# 	l 302 model_marital_Softmax_reduce_181_hlo_id_181__57   [49881] [F] ['i']
# 	l 304 mhlo_exponential_56   [49881, 2] [F,B] ['i', 'j']
# 	s 307 output1   [49881, 2] [F,B] ['i', 'j']
#
#
#
# mhlo_divide_42 - [49881, 8], tensor_layout: [P,F]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=391, num_pf_transposes=1, num_bf_transposes=1)
#  access_layout [B,P], accesses: ['246 L'], path: [[_pf_transpose,_pf_transpose], [_bf_transpose,_identity]]
#  access_layout [P,F], accesses: ['245 S'], path: [[_identity,_identity]]
# mhlo_divide_15 - [49881, 8], tensor_layout: [P,F]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=391, num_pf_transposes=1, num_bf_transposes=1)
#  access_layout [B,P], accesses: ['146 L'], path: [[_pf_transpose,_pf_transpose], [_bf_transpose,_identity]]
#  access_layout [P,F], accesses: ['145 S'], path: [[_identity,_identity]]
# mhlo_add_35 - [49881, 8], tensor_layout: [F,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=390, num_pf_transposes=1, num_bf_transposes=0)
#  access_layout [F,P], accesses: ['220 S'], path: [[_identity,_identity]]
#  access_layout [P,F], accesses: ['221 L', '228 L'], path: [[_pf_transpose,_pf_transpose]]
# mhlo_add_8 - [49881, 8], tensor_layout: [F,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=390, num_pf_transposes=1, num_bf_transposes=0)
#  access_layout [F,P], accesses: ['120 S'], path: [[_identity,_identity]]
#  access_layout [P,F], accesses: ['121 L', '128 L'], path: [[_pf_transpose,_pf_transpose]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_1_reduce_147_hlo_id_147__45 - [49881, 4], tensor_layout: [F,B]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [B,B], accesses: ['256 S'], path: [[_bf_transpose,_identity]]
#  access_layout [F,B], accesses: ['257 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Sum_reduce_99_hlo_id_99__18 - [49881, 4], tensor_layout: [F,B]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [B,B], accesses: ['156 S'], path: [[_bf_transpose,_identity]]
#  access_layout [F,B], accesses: ['157 L'], path: [[_identity,_identity]]
# mhlo_maximum_5 - [49881, 4, 8], tensor_layout: [F,B,P]
# tensor_transpose_cost(num_dmas=0, transpose_tripcount=4, num_pf_transposes=0, num_bf_transposes=1)
#  access_layout [F,B,P], accesses: ['109 S'], path: [[_identity,_identity,_identity]]
#  access_layout [B,B,P], accesses: ['148 L', '248 L'], path: [[_bf_transpose,_identity,_identity]]
# model_marital_Softmax_reduce_181_hlo_id_181__57 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['301 S', '302 L'], path: [[_identity]]
# mhlo_exponential_56 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['296 S', '297 L', '304 L'], path: [[_identity,_identity]]
# model_marital_Softmax_reduce_170_hlo_id_170__53 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['287 S', '288 L'], path: [[_identity]]
# mhlo_add_52 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['282 S', '283 L', '290 L'], path: [[_identity,_identity]]
# mhlo_maximum_49 - [49881, 8], tensor_layout: [F,P]
#  access_layout [F,P], accesses: ['271 S', '272 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_63_hlo_id_63__40 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['239 S', '240 L'], path: [[_identity]]
# mhlo_exponential_39 - [49881, 8], tensor_layout: [P,F]
#  access_layout [P,F], accesses: ['234 S', '235 L', '242 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_1_reduce_52_hlo_id_52__36 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['225 S', '226 L'], path: [[_identity]]
# model_income_Softmax_reduce_133_hlo_id_133__30 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['203 S', '204 L'], path: [[_identity]]
# mhlo_exponential_29 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['198 S', '199 L', '206 L'], path: [[_identity,_identity]]
# model_income_Softmax_reduce_122_hlo_id_122__26 - [49881], tensor_layout: [F]
#  access_layout [F], accesses: ['189 S', '190 L'], path: [[_identity]]
# mhlo_add_25 - [49881, 2], tensor_layout: [F,B]
#  access_layout [F,B], accesses: ['184 S', '185 L', '192 L'], path: [[_identity,_identity]]
# mhlo_maximum_22 - [49881, 8], tensor_layout: [F,P]
#  access_layout [F,P], accesses: ['173 S', '174 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_38_hlo_id_38__13 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['139 S', '140 L'], path: [[_identity]]
# mhlo_exponential_12 - [49881, 8], tensor_layout: [P,F]
#  access_layout [P,F], accesses: ['134 S', '135 L', '142 L'], path: [[_identity,_identity]]
# model_m_mo_e_StatefulPartitionedCall_StatefulPartitionedCall_Softmax_reduce_27_hlo_id_27__9 - [49881], tensor_layout: [P]
#  access_layout [P], accesses: ['125 S', '126 L'], path: [[_identity]]
# layoutgroup_profile(total_dmas=0, total_tripcount=406290, total_transpose_tripcount=1574, total_pf_transposes=4, total_bf_transposes=5, block_axes_tripcount=404716, parallel_axes_tripcount=4152, dags_no_parallelism=8)
#
# 20 MACROS WITH LARGEST INSTRUCTION COUNTS:
# 200704: matmul_8x1x1
# 200704: matmul_8x1x1
# 1568: transpose_128x128
# 1568: matmul_128x8x512
# 392: simd8x512
# 392: matmul_128x8x512
# 392: transpose_128x8
# 392: matmul_1x8x512
# 392: matmul_128x8x512
# 392: transpose_128x8
# 392: matmul_1x8x512
# 390: reduce8x1x128
# 390: simd128x8
# 390: reduce8x1x128
# 390: simd128x8
# 390: transpose_8x128
# 390: reduce8x1x128
# 390: simd128x8
# 390: reduce8x1x128
# 390: simd128x8
# f.num_dynamic_instances:  413344
# .....................................................................
# Compiler status PASS
# WARNING:tensorflow:Warning: Your traced model has 7.14285714285714% of operators compiled to neuron.

# %%
print(neuron_model.on_neuron_ratio)
# Out:
# 0.0714285714285714

# %%
#neuron_model.build(input_shape=test_data.shape)

# %%
test_data[:1]
# Out:
#     age  wage_per_hour  capital_gains  capital_losses  stock_dividends  \
# 0  38.0            0.0            0.0             0.0              0.0
#
#    instance_weight  num_emp  own_or_self  vet_benefits  weeks_worked  ...  \
# 0          1032.38      4.0          0.0           2.0          12.0  ...
#
#    country_self_ Yugoslavia  citizenship_ Foreign born- Not a citizen of U S   \
# 0                       0.0                                               1.0
#
#    citizenship_ Foreign born- U S citizen by naturalization  \
# 0                                                0.0
#
#    citizenship_ Native- Born abroad of American Parent(s)  \
# 0                                                0.0
#
#    citizenship_ Native- Born in Puerto Rico or U S Outlying  \
# 0                                                0.0
#
#    citizenship_ Native- Born in the United States  vet_question_ No  \
# 0                                             0.0               0.0
#
#    vet_question_ Not in universe  vet_question_ Yes  \
# 0                            1.0                0.0
#
#    det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily
# 0                                                0.0
#
# [1 rows x 499 columns]

# %%
neuron_model.predict(test_data[:10])
# Out:
# [array([[0.995628  , 0.00437197],
#         [0.995628  , 0.00437197],
#         [0.995628  , 0.00437197],
#         ...,
#         [0.9955972 , 0.00440288],
#         [0.9955972 , 0.00440288],
#         [0.9955972 , 0.00440288]], dtype=float32),
#  array([[9.91760373e-01, 8.23958777e-03],
#         [5.16981381e-05, 9.99948263e-01],
#         [1.21341494e-04, 9.99878645e-01],
#         ...,
#         [9.97491360e-01, 2.50861933e-03],
#         [9.97491360e-01, 2.50861933e-03],
#         [9.97491360e-01, 2.50861933e-03]], dtype=float32)]

# %%
neuron_dir = "./model/model_neuron"
neuron_model.save(neuron_dir)
# Out:
# INFO:tensorflow:Assets written to: ./model/model_neuron/assets

# %%
model_neuron_reloaded = tf.keras.models.load_model(neuron_dir)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
model_neuron_reloaded(test_data[:1])
# Out:
# [<tf.Tensor: shape=(49881, 2), dtype=float32, numpy=
#  array([[0.995628  , 0.00437197],
#         [0.9955972 , 0.00440288],
#         [0.9955972 , 0.00440288],
#         ...,
#         [0.9955972 , 0.00440288],
#         [0.9955972 , 0.00440288],
#         [0.9955972 , 0.00440288]], dtype=float32)>,
#  <tf.Tensor: shape=(49881, 2), dtype=float32, numpy=
#  array([[0.9917604 , 0.00823959],
#         [0.99749136, 0.00250862],
#         [0.99749136, 0.00250862],
#         ...,
#         [0.99749136, 0.00250862],
#         [0.99749136, 0.00250862],
#         [0.99749136, 0.00250862]], dtype=float32)>]
